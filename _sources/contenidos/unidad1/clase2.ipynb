# %% [markdown]
# # Quiénes integramos el proyecto AuMiLab
#
# ## Integrantes

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/equipo2.jpeg" width="450">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# # Primeros pasos en minería y etiquetas de clases en imágenes:
#
# ## 2018-2020. Tesis de pregrado, Ingeniero Civil en Informática, Víctor Vargas S.

# %% [markdown]
# + Sistema de reconocimiento automático de gestos estáticos del alfabeto de la lengua de señas chilena

# %% [markdown]
# <img src="../figuras/diagram_vv.png" width="650">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/detection_obj_vv.jpeg" width="300">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/biblio1.jpeg" width="350">

# %% [markdown]
# <br/><br/>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("yMAlNTehnwI", width=712, height=420)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("Aw_emy_Exqo", width=712, height=420)

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 2018-2020. Tesis de pregrado, Ingeniera Civil Acústico, Yetzabeth González C.

# %% [markdown]
# + Diseño e implementación de sistema de traducción de voz o texto, a lengua de señas Chilena mediante un avatar

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/alfabeto.png" width="650">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/diagrama.png" width="650">

# %% [markdown]
# <img src="../figuras/mhf.png" width="450">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/Screenshot_20200122_171145.png" width="250">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/movements.png" width="550">

# %% [markdown]
# <br/><br/>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("cKrSgEtiAms", width=712, height=420)

# %% [markdown]
# <br/><br/>

# %% [markdown]
# # Primeros pasos en minería y etiquetas de clases en audios
# ## 2019-2021 Proyecto de investigación Fondecyt
# + Investigador Principal: Dr. Felipe Otondo. Método de time-lapse sonoro para la puesta en valor del patrimonio sonoro de humedales urbanos.

# %% [markdown]
# ## Uso práctico de sound-time-lapse para espectrogramas de larga duración.
#
# > + Grabadores de audio.
# > + Grabaciones de paisajes sonoros en tres humedales urbanos Valdivianos.
# > + Grandes volúmenes de grabación: `1 año completo`
# > + Documentación de una base de datos.

# %% [markdown]
# <img src="../figuras/spectrogram_long.png" width="500">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/icmc.png" width="600">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## Enero 2021: Primer dataset de audios de humedales urbanos
#
# > + Miraflores,
# > + Parque Urbano,
# > + Angachille
#
# + 720 audios en total (de duración 5 min c/u).
# + Etiquetado fuerte:
#
# > + Una semana de Octubre 2019.
# > + Una semana de Enero 2020.
#
# + Usamos dos técnicas no lineales de reducción de dimensionalidad para visualización de **features**:
#
# > + UMAP - **Uniform Manifold Approximation and Projection**
# > + t-SNE - **t-distributed Stochastic Neighbor Embedding**
#
# + Utilizamos este dataset para entrenar un modelo de aprendizaje profundo basado en una red detectora de eventos sonoros polifónicos (SEDnet)
#
# > + Detectar automáticamente clases de eventos sonoros en los humedales urbanos

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/UMAP.png" width="600">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/prediction_GT.png" width="600">

# %% [markdown]
# <br/><br/>

# %% [markdown]
# <img src="../figuras/charact.png" width="600">

# %% [markdown]
# <br/><br/>
